# %% [markdown]
# The complete code for day 2 is on the following repository
# https://github.com/Fawas-Anayat/statistics_for_machine_learning
